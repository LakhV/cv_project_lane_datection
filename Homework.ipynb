# %% [markdown]
# # LANE DETECTION

# %% [markdown]
# This project is focused on detecting road lane lines using a combination of YOLO object detection and Hough Line Transform techniques. The goal is to create a lane detection system that combines the strengths of both methods for better accuracy, especially in detecting vertical lane lines (which are crucial for navigation and driving assistance systems)
#
# YOLO is not the first model I tried to integrate, previously it was LaneNet which was more specialized in line detection, but it was a completely unsuccessful experience. The pre-trained YOLO model (on TuSimple, CULane datasets) seemed redundant, as it involves not only lane/line detection, but also detection of many other road objects. Training my own fine-tuned lane/line weights turned out to be too time-consuming, so I settled on the pre-trained version.
#
# The model itself is not ideal in low light conditions or, as in the input example, with sunset conditions. So the idea was to improve lane detection based on Hough Line Transform line detection. Theoretically, the combination of methods should improve lane detection to allow the driving assistance system to better understand the vehicle’s position.
#
# Inputs:
# - Video file
# - YOLO Model (lane_trained.pt): pre-trained model is used to detect lane-related objects (such as lane lines, arrows, and other road markings)
#
# Output:
# - Annotated Frames and Lane Lines
# - Bounding Boxes: YOLO detects lane-related objects and draws bounding boxes around them
# - Vertical Lane Lines: Detected using Hough Line Transform, filtered for verticality
# - Annotations: Labels indicating lane types, e.g., ‘Line 1’, ‘Yellow Markings’
#
# Advantages:
# 1. Combining YOLO and Hough Transform:
# - YOLO is good in detecting objects (lane markings, arrows, etc.), which provides a great initial step in lane detection. It locates regions of interest quickly and with good accuracy.
# - Hough Line Transform is a robust method for detecting lines, particularly vertical lines, which are the most important for lane tracking. It should work well even in noisy or complex environments.
# 2. Filtering Horizontal Lines: By filtering out horizontal lines (which are irrelevant for lane detection), we focus only on vertical lane lines, improving the quality of the lane markings detected.
# 3. Efficient and Fast: This method uses YOLO for quick object detection followed by Hough Transform for precise line detection. It’s a hybrid approach that leverages the best of both techniques.
# 4. Adaptability: The solution can easily be adapted for different road types, lighting conditions, and lane configurations by fine-tuning the YOLO model.
#
# Disadvantages:
# 1. Quality of YOLO Model: the project relies on the pre-trained YOLO model. The model requires better fine tuniing and to be specialised on detection of road lines only.
# 2. Limited Detection of Curved Lanes: YOLO and Hough Lines are generally optimized for straight lines, so detecting curved lanes is more challenging.
# 3. Complexity of Pipeline: The system combines two methods, which increases complexity. Maintaining and fine-tuning the pipeline might require extra efforts.
# 4. False Positives/Negatives: In crowded/noicy scenes (e.g with many vehicles), the YOLO model might generate false positives (e.g. detecting other objects as lane lines), and Hough might struggle to detect lines in highly cluttered environments.
#
# Result:
#  At this point the result isn't quite great. The project requires extra tunning to improve lines detection in general, remove noicy output and better approach to draw lines for dashed lines.

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# Paths
MODEL_PATH = 'yolov8n.pt'
VIDEO_PATH = 'sunset.mp4'

# %%
# Pre-trained yolo model, my attempts to train it on TuSimple data set failed due to luck of resources and time
lane_model = YOLO('lane_trained.pt')

# Lane classes
lane_class_indices = [0, 1, 2, 3]  # extract line based classes, change depending on trained dataset

"""
Extract lane-related points from YOLO detections and filter out horizontal lines
"""
def process_yolo_detections(frame, results):
    left_lane_points = []
    right_lane_points = []

    for box in results[0].boxes.data:
        x1, y1, x2, y2, conf, cls = box
        cls = int(cls)

        # Filter only lane-related classes
        if cls in lane_class_indices:
            # Calculate the center of the bounding box
            box_center_x = (x1 + x2) / 2
            box_center_y = (y1 + y2) / 2

            # Filter out horizontal lines
            slope = (y2 - y1) / (x2 - x1 + 1e-6)
            if abs(slope) < 0.5:  # Adjust the threshold for filtering horizontal lines
                continue  # Skip this bounding box if it's horizontal

            # Assign to left or right lane based on x-position
            if box_center_x < frame.shape[1] // 2:
                left_lane_points.append(((x1 + x2) // 2, y2))
            else:
                right_lane_points.append(((x1 + x2) // 2, y2))

    return left_lane_points, right_lane_points

"""
Fit a line through points and draw it on the frame.
"""
def draw_lane_line(points, color, frame):
    if len(points) > 1:
        points = np.array(points, dtype=np.int32)
        [vx, vy, x, y] = cv2.fitLine(points, cv2.DIST_L2, 0, 0.01, 0.01)
        slope = vy / vx
        intercept = y - slope * x

        # Define the start and end points for the line
        y1 = frame.shape[0]
        y2 = int(frame.shape[0] * 0.6)
        x1 = int((y1 - intercept) / slope)
        x2 = int((y2 - intercept) / slope)

        cv2.line(frame, (x1, y1), (x2, y2), color, 2)

"""
Detect and draw additional lane lines using Hough Transform.
"""
def detect_hough_lines(frame, results):
    # prepare teh frame
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    edges = cv2.Canny(blurred, 50, 150)

    #Mask ROI
    mask = np.zeros_like(edges)
    height, width = frame.shape[:2]
    polygon = np.array([[
        (0, height),
        (width, height),
        (width // 2 + 100, height // 2),
        (width // 2 - 100, height // 2),
    ]], dtype=np.int32)
    cv2.fillPoly(mask, polygon, 255)
    roi_edges = cv2.bitwise_and(edges, mask)

    for box in results[0].boxes.data:
        x1, y1, x2, y2, _, _ = box
        cv2.rectangle(roi_edges, (int(x1), int(y1)), (int(x2), int(y2)), 0, -1)

    # Hough Line Transform
    lines = cv2.HoughLinesP(roi_edges, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=10)

    # Return Detected Lines
    hough_lines = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            # Filter out horizontal lines by checking the angle of the line
            slope = (y2 - y1) / (x2 - x1 + 1e-6)  # Avoid division by zero
            angle = np.arctan(slope) * 180 / np.pi  # Convert slope to angle in degrees

            # Filter out horizontal lines: we want lines with angles close to vertical
            if abs(angle) < 10 or abs(angle) > 170:  # For vertical lane lines, ignore near-horizontal lines
                continue

            hough_lines.append(((x1, y1), (x2, y2)))

    return hough_lines

"""
Draw Hough lines on the frame.
"""
def draw_hough_lines(hough_lines, frame):

    for line in hough_lines:
        (x1, y1), (x2, y2) = line
        color = (255, 0, 255) if x1 < frame.shape[1] // 2 else (0, 255, 255)  # Left magenta, Right yellow
        cv2.line(frame, (x1, y1), (x2, y2), color, 2)

def lane_detection_pipeline(original_frame):
    # Step 1: Make a copy for processing
    processing_frame = original_frame.copy()

    # Step 2: Run YOLO Model
    results = lane_model(processing_frame)

    # Step 3: Process YOLO Detections and Draw Boxes
    left_lane_points, right_lane_points = process_yolo_detections(processing_frame, results)
    
    # Draw YOLO Bounding Boxes
    for box in results[0].boxes.data:
        x1, y1, x2, y2, _, cls = box
        cls = int(cls)
        color = (255, 0, 0) if cls in lane_class_indices else (0, 255, 0)  # Blue for lanes, Green for others
        cv2.rectangle(processing_frame, (int(x1), int(y1)), (int(x2), int(y2)), color, 2)
        cv2.putText(processing_frame, lane_model.names[cls], (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Step 4: Detect Hough Lines
    hough_lines = detect_hough_lines(original_frame.copy(), results)

    # Step 5: Make a copy for visualization
    visualization_frame = processing_frame.copy()

    # Step 6: Draw YOLO and Hough results
    draw_lane_line(left_lane_points, (255, 0, 0), visualization_frame)  # Blue for left lane
    draw_lane_line(right_lane_points, (0, 0, 255), visualization_frame)  # Red for right lane
    draw_hough_lines(hough_lines, visualization_frame)

    return visualization_frame

# Main loop for testing
cap = cv2.VideoCapture(VIDEO_PATH)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Apply lane detection pipeline
    output_frame = lane_detection_pipeline(frame)

    # Display the result
    cv2.imshow('Lane Detection', output_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@0.535] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (2386) handleMessage OpenCV | GStreamer warning: your GStreamer installation is missing a required plugin
# [ WARN:0@0.535] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (2402) handleMessage OpenCV | GStreamer warning: Embedded video playback halted; module uridecodebin0 reported: Your GStreamer installation is missing a plug-in.
# [ WARN:0@0.535] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (1356) open OpenCV | GStreamer warning: unable to start pipeline
# [ WARN:0@0.535] global /private/var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_11nitadzeg/croot/opencv-suite_1691620374638/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# 0: 640x384 (no detections), 166.7ms
# Speed: 1.9ms preprocess, 166.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 164.4ms
# Speed: 7.0ms preprocess, 164.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.1ms
# Speed: 1.2ms preprocess, 152.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.9ms
# Speed: 1.2ms preprocess, 152.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.3ms
# Speed: 1.1ms preprocess, 153.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 151.9ms
# Speed: 1.4ms preprocess, 151.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 157.0ms
# Speed: 1.2ms preprocess, 157.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 162.1ms
# Speed: 1.6ms preprocess, 162.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 164.6ms
# Speed: 1.7ms preprocess, 164.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 155.6ms
# Speed: 1.2ms preprocess, 155.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.6ms
# Speed: 1.2ms preprocess, 158.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 159.7ms
# Speed: 2.4ms preprocess, 159.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 156.1ms
# Speed: 6.8ms preprocess, 156.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 153.9ms
# Speed: 1.4ms preprocess, 153.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 148.2ms
# Speed: 1.2ms preprocess, 148.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 150.0ms
# Speed: 2.1ms preprocess, 150.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 174.0ms
# Speed: 1.3ms preprocess, 174.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 169.0ms
# Speed: 1.8ms preprocess, 169.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 152.8ms
# Speed: 3.1ms preprocess, 152.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 154.8ms
# Speed: 1.3ms preprocess, 154.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 155.0ms
# Speed: 1.7ms preprocess, 155.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 157.8ms
# Speed: 1.1ms preprocess, 157.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 153.4ms
# Speed: 1.3ms preprocess, 153.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 159.9ms
# Speed: 1.2ms preprocess, 159.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 160.9ms
# Speed: 1.1ms preprocess, 160.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 156.4ms
# Speed: 2.6ms preprocess, 156.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.5ms
# Speed: 1.1ms preprocess, 148.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 153.3ms
# Speed: 1.3ms preprocess, 153.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.1ms
# Speed: 1.3ms preprocess, 149.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 151.7ms
# Speed: 1.1ms preprocess, 151.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 154.1ms
# Speed: 1.4ms preprocess, 154.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 154.7ms
# Speed: 1.1ms preprocess, 154.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.0ms
# Speed: 1.3ms preprocess, 158.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 169.7ms
# Speed: 1.2ms preprocess, 169.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 186.1ms
# Speed: 1.3ms preprocess, 186.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 200.1ms
# Speed: 1.4ms preprocess, 200.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 171.9ms
# Speed: 1.1ms preprocess, 171.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 159.6ms
# Speed: 1.1ms preprocess, 159.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 169.0ms
# Speed: 1.1ms preprocess, 169.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.8ms
# Speed: 1.2ms preprocess, 149.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.5ms
# Speed: 1.0ms preprocess, 152.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.6ms
# Speed: 1.4ms preprocess, 149.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 151.4ms
# Speed: 1.1ms preprocess, 151.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.2ms
# Speed: 1.1ms preprocess, 152.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.8ms
# Speed: 2.0ms preprocess, 149.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.3ms
# Speed: 1.1ms preprocess, 153.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.7ms
# Speed: 1.6ms preprocess, 148.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 167.1ms
# Speed: 1.3ms preprocess, 167.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 147.0ms
# Speed: 1.2ms preprocess, 147.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.8ms
# Speed: 2.4ms preprocess, 153.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 156.7ms
# Speed: 1.2ms preprocess, 156.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.6ms
# Speed: 1.2ms preprocess, 155.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.1ms
# Speed: 1.2ms preprocess, 148.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 154.9ms
# Speed: 4.5ms preprocess, 154.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.5ms
# Speed: 1.5ms preprocess, 148.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.8ms
# Speed: 1.2ms preprocess, 149.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.8ms
# Speed: 1.2ms preprocess, 152.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.8ms
# Speed: 1.3ms preprocess, 155.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 151.6ms
# Speed: 2.2ms preprocess, 151.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.4ms
# Speed: 1.2ms preprocess, 149.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 150.3ms
# Speed: 1.6ms preprocess, 150.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.2ms
# Speed: 1.1ms preprocess, 153.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 151.2ms
# Speed: 1.2ms preprocess, 151.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 156.4ms
# Speed: 1.7ms preprocess, 156.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 147.7ms
# Speed: 1.1ms preprocess, 147.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 154.3ms
# Speed: 1.1ms preprocess, 154.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 149.9ms
# Speed: 1.2ms preprocess, 149.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 161.4ms
# Speed: 5.3ms preprocess, 161.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 159.1ms
# Speed: 1.5ms preprocess, 159.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.6ms
# Speed: 1.7ms preprocess, 153.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 160.3ms
# Speed: 4.2ms preprocess, 160.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 168.3ms
# Speed: 1.4ms preprocess, 168.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 165.4ms
# Speed: 1.2ms preprocess, 165.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 159.6ms
# Speed: 2.0ms preprocess, 159.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 154.9ms
# Speed: 1.2ms preprocess, 154.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 156.4ms
# Speed: 1.1ms preprocess, 156.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.3ms
# Speed: 1.7ms preprocess, 155.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.2ms
# Speed: 1.2ms preprocess, 153.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.2ms
# Speed: 1.2ms preprocess, 153.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.6ms
# Speed: 1.0ms preprocess, 155.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.3ms
# Speed: 1.1ms preprocess, 153.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 161.0ms
# Speed: 3.4ms preprocess, 161.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 154.7ms
# Speed: 1.1ms preprocess, 154.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 148.7ms
# Speed: 1.2ms preprocess, 148.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 149.8ms
# Speed: 1.2ms preprocess, 149.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 148.6ms
# Speed: 1.2ms preprocess, 148.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 155.4ms
# Speed: 1.2ms preprocess, 155.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 155.4ms
# Speed: 1.1ms preprocess, 155.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 149.0ms
# Speed: 1.2ms preprocess, 149.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 154.2ms
# Speed: 1.3ms preprocess, 154.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 151.3ms
# Speed: 1.0ms preprocess, 151.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 154.9ms
# Speed: 1.1ms preprocess, 154.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.3ms
# Speed: 1.1ms preprocess, 157.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 154.5ms
# Speed: 1.3ms preprocess, 154.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.7ms
# Speed: 1.5ms preprocess, 155.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 169.2ms
# Speed: 3.8ms preprocess, 169.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.6ms
# Speed: 1.3ms preprocess, 157.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.4ms
# Speed: 1.0ms preprocess, 155.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.8ms
# Speed: 1.1ms preprocess, 157.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 151.2ms
# Speed: 1.1ms preprocess, 151.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 152.0ms
# Speed: 1.4ms preprocess, 152.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.9ms
# Speed: 2.1ms preprocess, 161.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.3ms
# Speed: 1.1ms preprocess, 155.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.1ms
# Speed: 1.2ms preprocess, 156.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.3ms
# Speed: 1.0ms preprocess, 159.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.3ms
# Speed: 1.2ms preprocess, 154.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.2ms
# Speed: 1.2ms preprocess, 154.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 157.2ms
# Speed: 1.3ms preprocess, 157.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 176.1ms
# Speed: 1.2ms preprocess, 176.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.5ms
# Speed: 1.2ms preprocess, 156.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.0ms
# Speed: 1.4ms preprocess, 157.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.6ms
# Speed: 1.1ms preprocess, 155.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.5ms
# Speed: 1.1ms preprocess, 158.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.1ms
# Speed: 1.6ms preprocess, 152.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.8ms
# Speed: 1.2ms preprocess, 155.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.6ms
# Speed: 1.1ms preprocess, 152.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 150.4ms
# Speed: 1.3ms preprocess, 150.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 147.8ms
# Speed: 1.3ms preprocess, 147.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.6ms
# Speed: 1.2ms preprocess, 153.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.0ms
# Speed: 1.0ms preprocess, 152.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 150.8ms
# Speed: 1.7ms preprocess, 150.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.3ms
# Speed: 1.2ms preprocess, 158.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.8ms
# Speed: 1.1ms preprocess, 153.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 165.7ms
# Speed: 3.4ms preprocess, 165.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.9ms
# Speed: 1.3ms preprocess, 154.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 154.0ms
# Speed: 1.2ms preprocess, 154.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 152.8ms
# Speed: 1.3ms preprocess, 152.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.0ms
# Speed: 1.5ms preprocess, 159.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 151.1ms
# Speed: 2.1ms preprocess, 151.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.0ms
# Speed: 1.2ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 153.4ms
# Speed: 1.2ms preprocess, 153.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 152.6ms
# Speed: 1.2ms preprocess, 152.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 170.1ms
# Speed: 1.4ms preprocess, 170.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 152.6ms
# Speed: 2.8ms preprocess, 152.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 153.4ms
# Speed: 1.3ms preprocess, 153.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 151.8ms
# Speed: 1.3ms preprocess, 151.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.1ms
# Speed: 1.7ms preprocess, 152.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 166.1ms
# Speed: 1.4ms preprocess, 166.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 166.0ms
# Speed: 6.7ms preprocess, 166.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 154.4ms
# Speed: 1.3ms preprocess, 154.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 155.1ms
# Speed: 1.4ms preprocess, 155.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 151.3ms
# Speed: 1.3ms preprocess, 151.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 156.6ms
# Speed: 1.3ms preprocess, 156.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 151.9ms
# Speed: 1.0ms preprocess, 151.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.3ms
# Speed: 1.2ms preprocess, 159.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.2ms
# Speed: 1.6ms preprocess, 156.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.4ms
# Speed: 1.3ms preprocess, 157.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.4ms
# Speed: 1.0ms preprocess, 152.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.8ms
# Speed: 1.7ms preprocess, 155.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 150.9ms
# Speed: 1.3ms preprocess, 150.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.8ms
# Speed: 1.6ms preprocess, 158.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.8ms
# Speed: 1.1ms preprocess, 154.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.2ms
# Speed: 1.2ms preprocess, 158.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 160.8ms
# Speed: 1.2ms preprocess, 160.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 170.9ms
# Speed: 5.2ms preprocess, 170.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 162.7ms
# Speed: 1.6ms preprocess, 162.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.4ms
# Speed: 1.2ms preprocess, 155.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.9ms
# Speed: 1.3ms preprocess, 153.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.6ms
# Speed: 1.6ms preprocess, 156.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.0ms
# Speed: 1.5ms preprocess, 158.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.1ms
# Speed: 1.3ms preprocess, 156.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.1ms
# Speed: 4.0ms preprocess, 153.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.4ms
# Speed: 1.6ms preprocess, 159.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 165.4ms
# Speed: 1.1ms preprocess, 165.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.1ms
# Speed: 1.3ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.1ms
# Speed: 1.2ms preprocess, 156.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 154.8ms
# Speed: 1.1ms preprocess, 154.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.1ms
# Speed: 1.4ms preprocess, 152.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.2ms
# Speed: 2.0ms preprocess, 156.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 161.6ms
# Speed: 6.4ms preprocess, 161.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 152.7ms
# Speed: 1.3ms preprocess, 152.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.4ms
# Speed: 2.1ms preprocess, 159.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.2ms
# Speed: 1.1ms preprocess, 155.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.7ms
# Speed: 3.6ms preprocess, 152.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.4ms
# Speed: 1.1ms preprocess, 159.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.2ms
# Speed: 2.7ms preprocess, 152.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.4ms
# Speed: 1.3ms preprocess, 154.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.3ms
# Speed: 2.6ms preprocess, 153.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.0ms
# Speed: 1.9ms preprocess, 154.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.1ms
# Speed: 1.2ms preprocess, 156.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.3ms
# Speed: 1.1ms preprocess, 155.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.5ms
# Speed: 3.6ms preprocess, 153.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.9ms
# Speed: 1.2ms preprocess, 152.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 162.8ms
# Speed: 1.8ms preprocess, 162.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 160.0ms
# Speed: 1.3ms preprocess, 160.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 149.8ms
# Speed: 1.3ms preprocess, 149.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.9ms
# Speed: 1.1ms preprocess, 156.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 154.3ms
# Speed: 2.1ms preprocess, 154.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.8ms
# Speed: 1.4ms preprocess, 156.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 152.6ms
# Speed: 1.2ms preprocess, 152.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.6ms
# Speed: 1.2ms preprocess, 158.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.1ms
# Speed: 1.2ms preprocess, 154.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.4ms
# Speed: 1.1ms preprocess, 157.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 154.1ms
# Speed: 1.3ms preprocess, 154.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 179.2ms
# Speed: 1.1ms preprocess, 179.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.7ms
# Speed: 1.4ms preprocess, 154.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 174.7ms
# Speed: 1.6ms preprocess, 174.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 159.0ms
# Speed: 1.5ms preprocess, 159.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.5ms
# Speed: 1.1ms preprocess, 156.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 151.1ms
# Speed: 1.1ms preprocess, 151.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 157.7ms
# Speed: 1.2ms preprocess, 157.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 155.1ms
# Speed: 2.0ms preprocess, 155.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.2ms
# Speed: 1.2ms preprocess, 156.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.3ms
# Speed: 1.1ms preprocess, 156.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 153.4ms
# Speed: 1.4ms preprocess, 153.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 154.0ms
# Speed: 1.1ms preprocess, 154.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 154.9ms
# Speed: 1.3ms preprocess, 154.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 154.1ms
# Speed: 1.2ms preprocess, 154.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 171.5ms
# Speed: 1.1ms preprocess, 171.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 157.8ms
# Speed: 1.4ms preprocess, 157.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 152.8ms
# Speed: 1.1ms preprocess, 152.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 157.6ms
# Speed: 1.4ms preprocess, 157.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 165.6ms
# Speed: 2.4ms preprocess, 165.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 163.1ms
# Speed: 1.4ms preprocess, 163.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 152.8ms
# Speed: 1.1ms preprocess, 152.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 155.9ms
# Speed: 1.1ms preprocess, 155.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 158.0ms
# Speed: 1.1ms preprocess, 158.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 155.1ms
# Speed: 1.1ms preprocess, 155.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 159.7ms
# Speed: 1.1ms preprocess, 159.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 169.7ms
# Speed: 1.1ms preprocess, 169.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 158.4ms
# Speed: 1.2ms preprocess, 158.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 160.4ms
# Speed: 1.1ms preprocess, 160.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 155.1ms
# Speed: 1.1ms preprocess, 155.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.1ms
# Speed: 1.5ms preprocess, 156.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 160.6ms
# Speed: 1.4ms preprocess, 160.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 159.9ms
# Speed: 1.3ms preprocess, 159.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 158.5ms
# Speed: 1.1ms preprocess, 158.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 154.7ms
# Speed: 1.0ms preprocess, 154.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 156.6ms
# Speed: 1.1ms preprocess, 156.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 158.6ms
# Speed: 1.0ms preprocess, 158.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 162.4ms
# Speed: 3.3ms preprocess, 162.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 155.7ms
# Speed: 1.2ms preprocess, 155.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 156.9ms
# Speed: 1.4ms preprocess, 156.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 148.0ms
# Speed: 2.3ms preprocess, 148.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 159.1ms
# Speed: 1.2ms preprocess, 159.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 150.7ms
# Speed: 1.1ms preprocess, 150.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 155.7ms
# Speed: 1.3ms preprocess, 155.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 159.3ms
# Speed: 1.2ms preprocess, 159.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 155.8ms
# Speed: 1.5ms preprocess, 155.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 155.8ms
# Speed: 1.6ms preprocess, 155.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 159.1ms
# Speed: 1.3ms preprocess, 159.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 167.6ms
# Speed: 7.3ms preprocess, 167.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.8ms
# Speed: 1.3ms preprocess, 156.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 155.4ms
# Speed: 1.1ms preprocess, 155.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 160.6ms
# Speed: 1.1ms preprocess, 160.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 154.5ms
# Speed: 1.9ms preprocess, 154.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 159.4ms
# Speed: 1.3ms preprocess, 159.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 157.7ms
# Speed: 1.2ms preprocess, 157.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 157.8ms
# Speed: 1.6ms preprocess, 157.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 160.9ms
# Speed: 1.2ms preprocess, 160.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 156.6ms
# Speed: 1.5ms preprocess, 156.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 173.4ms
# Speed: 1.4ms preprocess, 173.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 153.6ms
# Speed: 1.0ms preprocess, 153.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 153.7ms
# Speed: 1.3ms preprocess, 153.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 156.8ms
# Speed: 1.3ms preprocess, 156.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 175.8ms
# Speed: 1.5ms preprocess, 175.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 1 Line 2, 160.4ms
# Speed: 1.4ms preprocess, 160.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 1 Line 2, 159.2ms
# Speed: 1.2ms preprocess, 159.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 1 Line 2, 155.6ms
# Speed: 1.9ms preprocess, 155.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 154.2ms
# Speed: 1.5ms preprocess, 154.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 159.0ms
# Speed: 1.2ms preprocess, 159.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 169.0ms
# Speed: 4.6ms preprocess, 169.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 158.3ms
# Speed: 1.1ms preprocess, 158.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 158.5ms
# Speed: 1.6ms preprocess, 158.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 Line 1s, 162.1ms
# Speed: 1.1ms preprocess, 162.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 154.9ms
# Speed: 1.1ms preprocess, 154.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 155.8ms
# Speed: 1.8ms preprocess, 155.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 1 Line 2, 157.7ms
# Speed: 1.4ms preprocess, 157.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.0ms
# Speed: 4.9ms preprocess, 156.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 158.8ms
# Speed: 1.1ms preprocess, 158.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 160.7ms
# Speed: 1.5ms preprocess, 160.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 163.9ms
# Speed: 3.8ms preprocess, 163.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 158.0ms
# Speed: 1.6ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 159.1ms
# Speed: 1.6ms preprocess, 159.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 154.1ms
# Speed: 1.5ms preprocess, 154.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 155.9ms
# Speed: 1.2ms preprocess, 155.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 156.9ms
# Speed: 1.2ms preprocess, 156.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 Line 1s, 157.5ms
# Speed: 1.0ms preprocess, 157.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 Line 1s, 155.2ms
# Speed: 1.2ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 9 Line 1s, 156.1ms
# Speed: 1.2ms preprocess, 156.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 Line 1s, 171.8ms
# Speed: 2.3ms preprocess, 171.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 162.1ms
# Speed: 1.2ms preprocess, 162.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 164.3ms
# Speed: 1.3ms preprocess, 164.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 159.5ms
# Speed: 1.2ms preprocess, 159.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 152.9ms
# Speed: 1.2ms preprocess, 152.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.8ms
# Speed: 1.2ms preprocess, 154.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 167.1ms
# Speed: 1.1ms preprocess, 167.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 Line 1s, 156.3ms
# Speed: 1.3ms preprocess, 156.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 157.9ms
# Speed: 1.2ms preprocess, 157.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 160.6ms
# Speed: 3.5ms preprocess, 160.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 157.5ms
# Speed: 1.3ms preprocess, 157.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 158.5ms
# Speed: 1.4ms preprocess, 158.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 153.8ms
# Speed: 1.2ms preprocess, 153.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 158.5ms
# Speed: 1.1ms preprocess, 158.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 163.8ms
# Speed: 1.4ms preprocess, 163.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 150.0ms
# Speed: 1.2ms preprocess, 150.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 159.6ms
# Speed: 1.2ms preprocess, 159.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 156.8ms
# Speed: 1.1ms preprocess, 156.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 175.4ms
# Speed: 1.8ms preprocess, 175.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 157.6ms
# Speed: 1.3ms preprocess, 157.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.8ms
# Speed: 1.2ms preprocess, 156.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 155.7ms
# Speed: 1.3ms preprocess, 155.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 157.9ms
# Speed: 1.2ms preprocess, 157.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 157.5ms
# Speed: 1.9ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 Line 1s, 160.8ms
# Speed: 1.2ms preprocess, 160.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 156.8ms
# Speed: 1.6ms preprocess, 156.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 176.5ms
# Speed: 1.2ms preprocess, 176.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 157.1ms
# Speed: 1.3ms preprocess, 157.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 176.3ms
# Speed: 1.1ms preprocess, 176.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.8ms
# Speed: 1.5ms preprocess, 158.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 160.9ms
# Speed: 1.6ms preprocess, 160.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.4ms
# Speed: 1.2ms preprocess, 158.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 154.1ms
# Speed: 1.4ms preprocess, 154.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 155.7ms
# Speed: 1.3ms preprocess, 155.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 165.4ms
# Speed: 1.3ms preprocess, 165.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.2ms
# Speed: 2.1ms preprocess, 158.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 160.6ms
# Speed: 1.2ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 159.0ms
# Speed: 1.5ms preprocess, 159.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 153.4ms
# Speed: 1.1ms preprocess, 153.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.3ms
# Speed: 2.2ms preprocess, 155.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.8ms
# Speed: 1.3ms preprocess, 152.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.2ms
# Speed: 1.2ms preprocess, 158.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 169.2ms
# Speed: 1.4ms preprocess, 169.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.8ms
# Speed: 1.4ms preprocess, 158.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.1ms
# Speed: 1.4ms preprocess, 155.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 157.6ms
# Speed: 1.3ms preprocess, 157.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 161.5ms
# Speed: 1.9ms preprocess, 161.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 162.5ms
# Speed: 2.7ms preprocess, 162.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 160.8ms
# Speed: 1.3ms preprocess, 160.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 162.2ms
# Speed: 1.3ms preprocess, 162.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 171.3ms
# Speed: 2.1ms preprocess, 171.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 157.3ms
# Speed: 1.2ms preprocess, 157.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 152.7ms
# Speed: 5.4ms preprocess, 152.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 157.7ms
# Speed: 1.3ms preprocess, 157.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 155.8ms
# Speed: 1.7ms preprocess, 155.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 156.3ms
# Speed: 1.2ms preprocess, 156.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 158.6ms
# Speed: 1.2ms preprocess, 158.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 157.5ms
# Speed: 1.3ms preprocess, 157.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 168.0ms
# Speed: 4.4ms preprocess, 168.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 163.6ms
# Speed: 1.1ms preprocess, 163.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 160.9ms
# Speed: 1.2ms preprocess, 160.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 156.8ms
# Speed: 1.5ms preprocess, 156.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 Line 1, 157.1ms
# Speed: 1.4ms preprocess, 157.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 153.1ms
# Speed: 1.4ms preprocess, 153.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 152.1ms
# Speed: 1.5ms preprocess, 152.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 163.3ms
# Speed: 1.3ms preprocess, 163.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 166.0ms
# Speed: 6.3ms preprocess, 166.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.7ms
# Speed: 1.2ms preprocess, 161.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 158.6ms
# Speed: 1.4ms preprocess, 158.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.4ms
# Speed: 1.5ms preprocess, 158.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.1ms
# Speed: 2.3ms preprocess, 161.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 158.2ms
# Speed: 1.6ms preprocess, 158.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 160.5ms
# Speed: 1.3ms preprocess, 160.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 175.5ms
# Speed: 1.2ms preprocess, 175.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 154.3ms
# Speed: 1.2ms preprocess, 154.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 163.2ms
# Speed: 1.4ms preprocess, 163.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 157.5ms
# Speed: 1.3ms preprocess, 157.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 157.9ms
# Speed: 2.2ms preprocess, 157.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 160.2ms
# Speed: 1.9ms preprocess, 160.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 Line 1s, 160.2ms
# ...
#
# 0: 640x384 4 Line 1s, 158.6ms
# Speed: 1.2ms preprocess, 158.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 174.3ms
# Speed: 1.1ms preprocess, 174.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.9ms
# Speed: 1.2ms preprocess, 157.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 155.2ms
# Speed: 2.0ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 160.5ms
# Speed: 1.2ms preprocess, 160.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 161.6ms
# Speed: 1.5ms preprocess, 161.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 170.9ms
# Speed: 1.1ms preprocess, 170.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.1ms
# Speed: 1.2ms preprocess, 159.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 160.4ms
# Speed: 1.1ms preprocess, 160.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 162.5ms
# Speed: 1.2ms preprocess, 162.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.3ms
# Speed: 1.1ms preprocess, 157.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 171.5ms
# Speed: 1.6ms preprocess, 171.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 161.1ms
# Speed: 1.2ms preprocess, 161.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.3ms
# Speed: 1.0ms preprocess, 157.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 157.3ms
# Speed: 4.7ms preprocess, 157.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 164.0ms
# Speed: 1.2ms preprocess, 164.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 178.4ms
# Speed: 1.6ms preprocess, 178.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 162.3ms
# Speed: 1.1ms preprocess, 162.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 153.9ms
# Speed: 1.0ms preprocess, 153.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 160.9ms
# Speed: 1.2ms preprocess, 160.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.2ms
# Speed: 1.1ms preprocess, 159.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 173.2ms
# Speed: 1.1ms preprocess, 173.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.0ms
# Speed: 1.3ms preprocess, 156.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 166.9ms
# Speed: 1.1ms preprocess, 166.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.1ms
# Speed: 1.2ms preprocess, 159.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.8ms
# Speed: 1.2ms preprocess, 161.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 184.7ms
# Speed: 1.2ms preprocess, 184.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 155.7ms
# Speed: 1.0ms preprocess, 155.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 163.4ms
# Speed: 1.0ms preprocess, 163.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.7ms
# Speed: 1.1ms preprocess, 156.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 161.7ms
# Speed: 1.2ms preprocess, 161.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 173.9ms
# Speed: 1.0ms preprocess, 173.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 181.1ms
# Speed: 1.0ms preprocess, 181.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 171.1ms
# Speed: 1.2ms preprocess, 171.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 163.6ms
# Speed: 1.5ms preprocess, 163.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 161.4ms
# Speed: 1.5ms preprocess, 161.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 174.5ms
# Speed: 1.1ms preprocess, 174.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.4ms
# Speed: 1.1ms preprocess, 159.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.7ms
# Speed: 1.2ms preprocess, 161.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.0ms
# Speed: 1.2ms preprocess, 161.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.6ms
# Speed: 1.1ms preprocess, 156.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 183.3ms
# Speed: 1.2ms preprocess, 183.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 206.2ms
# Speed: 1.2ms preprocess, 206.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 165.9ms
# Speed: 1.2ms preprocess, 165.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 165.9ms
# Speed: 1.2ms preprocess, 165.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.6ms
# Speed: 1.6ms preprocess, 159.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 170.9ms
# Speed: 1.2ms preprocess, 170.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 153.5ms
# Speed: 1.2ms preprocess, 153.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 176.4ms
# Speed: 1.8ms preprocess, 176.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 182.3ms
# Speed: 1.6ms preprocess, 182.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 160.7ms
# Speed: 1.2ms preprocess, 160.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 179.9ms
# Speed: 1.3ms preprocess, 179.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 163.9ms
# Speed: 1.1ms preprocess, 163.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.9ms
# Speed: 1.1ms preprocess, 157.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 168.4ms
# Speed: 1.2ms preprocess, 168.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 174.3ms
# Speed: 1.2ms preprocess, 174.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 160.5ms
# Speed: 1.3ms preprocess, 160.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.0ms
# Speed: 2.2ms preprocess, 158.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.6ms
# Speed: 1.2ms preprocess, 161.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 175.0ms
# Speed: 1.2ms preprocess, 175.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 158.8ms
# Speed: 1.2ms preprocess, 158.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 161.2ms
# Speed: 1.2ms preprocess, 161.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.5ms
# Speed: 1.2ms preprocess, 155.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 174.6ms
# Speed: 1.2ms preprocess, 174.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 156.9ms
# Speed: 1.0ms preprocess, 156.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 163.4ms
# Speed: 1.2ms preprocess, 163.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.1ms
# Speed: 1.1ms preprocess, 159.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 175.0ms
# Speed: 1.3ms preprocess, 175.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.9ms
# Speed: 1.3ms preprocess, 159.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.2ms
# Speed: 1.1ms preprocess, 159.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.4ms
# Speed: 1.1ms preprocess, 157.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 174.2ms
# Speed: 5.3ms preprocess, 174.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.7ms
# Speed: 1.0ms preprocess, 159.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.3ms
# Speed: 1.2ms preprocess, 156.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.3ms
# Speed: 2.3ms preprocess, 158.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 174.6ms
# Speed: 1.2ms preprocess, 174.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 164.8ms
# Speed: 1.3ms preprocess, 164.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 165.3ms
# Speed: 1.1ms preprocess, 165.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 161.3ms
# Speed: 1.5ms preprocess, 161.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 183.1ms
# Speed: 1.1ms preprocess, 183.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 156.4ms
# Speed: 1.3ms preprocess, 156.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 164.8ms
# Speed: 1.2ms preprocess, 164.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 162.3ms
# Speed: 1.1ms preprocess, 162.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 170.6ms
# Speed: 1.2ms preprocess, 170.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.1ms
# Speed: 2.0ms preprocess, 158.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 164.4ms
# Speed: 1.2ms preprocess, 164.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 164.2ms
# Speed: 2.2ms preprocess, 164.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 166.6ms
# Speed: 1.2ms preprocess, 166.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 155.0ms
# Speed: 1.6ms preprocess, 155.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.8ms
# Speed: 1.0ms preprocess, 158.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.2ms
# Speed: 1.6ms preprocess, 157.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 176.4ms
# Speed: 1.2ms preprocess, 176.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.2ms
# Speed: 1.1ms preprocess, 157.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 161.8ms
# Speed: 1.0ms preprocess, 161.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 155.7ms
# Speed: 1.2ms preprocess, 155.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 174.7ms
# Speed: 1.1ms preprocess, 174.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.9ms
# Speed: 1.1ms preprocess, 158.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 155.2ms
# Speed: 1.2ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 160.8ms
# Speed: 1.1ms preprocess, 160.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 178.9ms
# Speed: 1.1ms preprocess, 178.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 160.1ms
# Speed: 1.8ms preprocess, 160.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 Line 1s, 159.2ms
# Speed: 1.4ms preprocess, 159.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.2ms
# Speed: 1.2ms preprocess, 159.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 210.4ms
# Speed: 1.1ms preprocess, 210.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.2ms
# Speed: 1.3ms preprocess, 159.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.6ms
# Speed: 1.2ms preprocess, 158.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 167.5ms
# Speed: 1.3ms preprocess, 167.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 184.2ms
# Speed: 1.2ms preprocess, 184.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 158.6ms
# Speed: 1.2ms preprocess, 158.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 168.1ms
# Speed: 1.2ms preprocess, 168.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.3ms
# Speed: 1.0ms preprocess, 157.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 188.1ms
# Speed: 1.4ms preprocess, 188.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 165.4ms
# Speed: 1.6ms preprocess, 165.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 162.7ms
# Speed: 1.1ms preprocess, 162.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 160.6ms
# Speed: 1.2ms preprocess, 160.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 187.2ms
# Speed: 1.2ms preprocess, 187.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 Line 1s, 163.1ms
# Speed: 1.3ms preprocess, 163.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 157.6ms
# Speed: 1.4ms preprocess, 157.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 171.0ms
# Speed: 1.6ms preprocess, 171.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 173.3ms
# Speed: 1.7ms preprocess, 173.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 159.1ms
# Speed: 1.2ms preprocess, 159.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 165.6ms
# Speed: 1.1ms preprocess, 165.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 173.6ms
# Speed: 1.1ms preprocess, 173.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 Line 1s, 172.5ms
# Speed: 1.4ms preprocess, 172.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 384)
